# %%
from plato.environment import Environment

# %%
config = {
  "whites":{
    "params":{
    "n_white_infantry":5,
    "n_white_vehicle":2,
    "n_white_drone":1},
    "init":"NW"
  },

  "blacks":{
    "params":{
    "n_black_infantry":5,
    "n_black_vehicle":2,
    "n_black_drone":1},
    "init":"SE"
  }
}

# %%
sim = Environment(config, shape=(60,60))

# %%
obs = sim.reset()

# %%
for id_,w in sim.whites.items(): print('{:13}'.format(id_), w)
# Out:
# HOLLYWOOD     <plato.entity.infantry.Infantry object at 0x110108a90>
# FLAGSTAFF     <plato.entity.infantry.Infantry object at 0x11002c710>
# CHICAGO       <plato.entity.infantry.Infantry object at 0x11011a210>
# INDEPENDENCE  <plato.entity.infantry.Infantry object at 0x11011a250>
# CHICKASAW     <plato.entity.infantry.Infantry object at 0x1101176d0>
# SHELLDRAKE    <plato.entity.vehicle.Vehicle object at 0x11011a1d0>
# STUTTGART     <plato.entity.vehicle.Vehicle object at 0x10f925750>
# ATLANTA       <plato.entity.drone.Drone object at 0x110121e50>

# %%
for id_,w in sim.blacks.items(): print('{:13}'.format(id_), w)
# Out:
# unknown_0     <plato.entity.infantry.Infantry object at 0x1101251d0>
# unknown_1     <plato.entity.infantry.Infantry object at 0x110125210>
# unknown_2     <plato.entity.infantry.Infantry object at 0x1101287d0>
# unknown_3     <plato.entity.infantry.Infantry object at 0x110128810>
# unknown_4     <plato.entity.infantry.Infantry object at 0x110125cd0>
# unknown_5     <plato.entity.vehicle.Vehicle object at 0x1101250d0>
# unknown_6     <plato.entity.vehicle.Vehicle object at 0x11012b850>
# unknown_7     <plato.entity.drone.Drone object at 0x11012e490>

# %%
canvas = sim.render()
